# %%
import sys
# !{sys.executable} -m pip install pandas matplotlib seaborn scipy requests
# Out:
# Requirement already satisfied: pandas in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (3.0.1)
# Requirement already satisfied: matplotlib in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (0.13.2)
# Requirement already satisfied: scipy in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (1.17.1)
# Requirement already satisfied: requests in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (2.32.5)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from requests) (2026.2.25)
# Requirement already satisfied: six>=1.5 in c:\users\abdur\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\abdur\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import requests

print("All libraries loaded successfully!")
# Out:
# All libraries loaded successfully!

# %%
import requests
import pandas as pd

# Fetch VCT Masters and Champions 2025 events
url = "https://vlrggapi.vercel.app/match/results?page=1"
response = requests.get(url)
print(response.status_code)
print(response.json())
# Out:
# 402
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 8
#       6 response = requests.get(url)
#       7 print(response.status_code)
# ----> 8 print(response.json())
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
url = "https://vlrggapi.vercel.app/events?q=upcoming"
response = requests.get(url)
print(response.status_code) 
print(response.json())
# Out:
# 402
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 4
#       2 response = requests.get(url)
#       3 print(response.status_code)
# ----> 4 print(response.json())
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
url = "https://vlrggapi.vercel.app/events?q=completed"
response = requests.get(url)
print(response.status_code)
import json
data = response.json()
# Show just the titles to find Masters/Champions 2025
for event in data['data']['segments']:
    print(event['title'], '-', event['dates'])

# %%
url = "https://vlrggapi.vercel.app/events?q=completed&page=2"
response = requests.get(url)
data = response.json()
for event in data['data']['segments']:
    print(event['title'], '-', event['dates'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 3
#       1 url = "https://vlrggapi.vercel.app/events?q=completed&page=2"
#       2 response = requests.get(url)
# ----> 3 data = response.json()
#       4 for event in data['data']['segments']:
#       5     print(event['title'], '-', event['dates'])
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
url = "https://vlrggapi.vercel.app/events?q=completed&page=3"
response = requests.get(url)
data = response.json()
for event in data['data']['segments']:
    print(event['title'], '-', event['dates'])

# %%
url = "https://vlrggapi.vercel.app/events?q=completed&page=4"
response = requests.get(url)
data = response.json()
for event in data['data']['segments']:
    print(event['title'], '-', event['dates'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 url = "https://vlrggapi.vercel.app/events?q=completed&page=4"
#       2 response = requests.get(url)
# ----> 3 data = response.json()
#       4 for event in data['data']['segments']:
#       5     print(event['title'], '-', event['dates'])
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
url = "https://vlrggapi.vercel.app/events?q=completed&page=5"
response = requests.get(url)
data = response.json()
for event in data['data']['segments']:
    print(event['title'], '-', event['dates'])

# %%
url = "https://vlrggapi.vercel.app/events?q=completed&page=5"
response = requests.get(url)
data = response.json()
for event in data['data']['segments']:
    if 'Champions' in event['title'] or 'Masters' in event['title']:
        print(event['title'], '-', event['url_path'])

# %%
for page in [6, 7]:
    url = f"https://vlrggapi.vercel.app/events?q=completed&page={page}"
    response = requests.get(url)
    data = response.json()
    for event in data['data']['segments']:
        if 'Champions' in event['title'] or 'Masters' in event['title']:
            print(event['title'], '-', event['url_path'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 4
#       2 url = f"https://vlrggapi.vercel.app/events?q=completed&page={page}"
#       3 response = requests.get(url)
# ----> 4 data = response.json()
#       5 for event in data['data']['segments']:
#       6     if 'Champions' in event['title'] or 'Masters' in event['title']:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
for page in [7, 8, 9]:
    url = f"https://vlrggapi.vercel.app/events?q=completed&page={page}"
    response = requests.get(url)
    data = response.json()
    for event in data['data']['segments']:
        if 'Masters' in event['title'] and '2025' in event['title']:
            print(event['title'], '-', event['url_path'])

# %%
for page in [9, 10, 11]:
    url = f"https://vlrggapi.vercel.app/events?q=completed&page={page}"
    response = requests.get(url)
    data = response.json()
    for event in data['data']['segments']:
        if 'Masters' in event['title'] and '2025' in event['title']:
            print(event['title'], '-', event['url_path'])

# %%
url = "https://vlrggapi.vercel.app/match/results?event_id=2283"
response = requests.get(url)
print(response.status_code)
print(response.json())

# %%
# Try different match endpoints
endpoints = [
    "https://vlrggapi.vercel.app/match?q=completed",
    "https://vlrggapi.vercel.app/matches?event_id=2283",
    "https://vlrggapi.vercel.app/stats?event_id=2283",
]

for ep in endpoints:
    r = requests.get(ep)
    print(ep, '-', r.status_code)
# Out:
# https://vlrggapi.vercel.app/match?q=completed - 402
# https://vlrggapi.vercel.app/matches?event_id=2283 - 402
# https://vlrggapi.vercel.app/stats?event_id=2283 - 402

# %%
url = "https://vlrggapi.vercel.app/match?q=completed"
response = requests.get(url)
data = response.json()
print(data.keys())
# Show first match
print(data['data']['segments'][0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 url = "https://vlrggapi.vercel.app/match?q=completed"
#       2 response = requests.get(url)
# ----> 3 data = response.json()
#       4 print(data.keys())
#       5 # Show first match
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
url = "https://vlrggapi.vercel.app/match?q=completed"
response = requests.get(url)
data = response.json()
print(data)

# %%
# Try fetching VLR.gg stats page directly
url = "https://www.vlr.gg/event/stats/2283/valorant-champions-2025"
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
print(response.status_code)
print(response.text[:2000])

# %%
import sys
# !{sys.executable} -m pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

url = "https://www.vlr.gg/event/stats/2283/valorant-champions-2025"
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table')
rows = table.find_all('tr')

data = []
for row in rows:
    cols = [col.get_text(strip=True) for col in row.find_all(['td', 'th'])]
    if cols:
        data.append(cols)

df = pd.DataFrame(data[1:], columns=data[0])
print(df.shape)
print(df.head())

# %%
events = {
    'Masters Bangkok 2025': 'https://www.vlr.gg/event/stats/2281/valorant-masters-bangkok-2025',
    'Masters Toronto 2025': 'https://www.vlr.gg/event/stats/2282/valorant-masters-toronto-2025',
    'Champions 2025': 'https://www.vlr.gg/event/stats/2283/valorant-champions-2025'
}

headers = {'User-Agent': 'Mozilla/5.0'}
all_dfs = []

for event_name, url in events.items():
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find('table')
    rows = table.find_all('tr')
    data = []
    for row in rows:
        cols = [col.get_text(strip=True) for col in row.find_all(['td', 'th'])]
        if cols:
            data.append(cols)
    df = pd.DataFrame(data[1:], columns=data[0])
    df['Event'] = event_name
    all_dfs.append(df)
    print(f"{event_name}: {df.shape[0]} players")

combined_df = pd.concat(all_dfs, ignore_index=True)
print(f"\nTotal: {combined_df.shape[0]} rows, {combined_df.shape[1]} columns")
print(combined_df.head())

# %%
combined_df.to_csv('vct_2025_stats.csv', index=False)
print("Saved to vct_2025_stats.csv")

# %%
print(combined_df['Player'].unique())
print(combined_df.columns.tolist())

# %%
print(combined_df.columns.tolist())

# %%
# Check the raw HTML for team info in the stats table
url = "https://www.vlr.gg/event/stats/2283/valorant-champions-2025"
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table')
# Print first 3 rows raw HTML to see what's in there
rows = table.find_all('tr')
for row in rows[1:4]:
    print(row)
    print('---')

# %%
def scrape_event(url, event_name):
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find('table')
    rows = table.find_all('tr')[1:]  # skip header
    
    data = []
    for row in rows:
        cols = row.find_all(['td', 'th'])
        if not cols:
            continue
        
        # Get player name
        player = row.find('div', class_='text-of')
        player_name = player.get_text(strip=True) if player else ''
        
        # Get team name
        team_div = row.find('div', class_='stats-player-country')
        team = team_div.get_text(strip=True) if team_div else ''
        
        # Get all stat values
        stat_cols = [col.get_text(strip=True) for col in cols]
        
        row_data = [player_name, team] + stat_cols[1:]  # skip first col, add player+team
        data.append(row_data)
    
    # Get headers
    header_row = table.find('tr')
    headers_list = ['Player', 'Team'] + [col.get_text(strip=True) for col in header_row.find_all(['td','th'])][1:]
    
    df = pd.DataFrame(data, columns=headers_list)
    df['Event'] = event_name
    return df

events = {
    'Masters Bangkok 2025': 'https://www.vlr.gg/event/stats/2281/valorant-masters-bangkok-2025',
    'Masters Toronto 2025': 'https://www.vlr.gg/event/stats/2282/valorant-masters-toronto-2025',
    'Champions 2025': 'https://www.vlr.gg/event/stats/2283/valorant-champions-2025'
}

all_dfs = []
for event_name, url in events.items():
    df = scrape_event(url, event_name)
    all_dfs.append(df)
    print(f"{event_name}: {df.shape[0]} players")

combined_df = pd.concat(all_dfs, ignore_index=True)
print(combined_df[['Player', 'Team', 'Event']].head(10))

# %%
team_region = {
    # Americas
    'MIBR': 'Americas', 'NRG': 'Americas', 'SEN': 'Americas', 'C9': 'Americas',
    'EG': 'Americas', 'LOUD': 'Americas', 'LEV': 'Americas', '100T': 'Americas',
    'G2': 'Americas', '2G': 'Americas', 'KRU': 'Americas',
    # EMEA
    'TL': 'EMEA', 'TH': 'EMEA', 'FNC': 'EMEA', 'VIT': 'EMEA', 'NAVI': 'EMEA',
    'BBL': 'EMEA', 'GX': 'EMEA', 'KC': 'EMEA', 'M8': 'EMEA', 'FUT': 'EMEA',
    # Pacific
    'T1': 'Pacific', 'DRX': 'Pacific', 'PRX': 'Pacific', 'TLN': 'Pacific',
    'TS': 'Pacific', 'GEN': 'Pacific', 'RRQ': 'Pacific', 'ZETA': 'Pacific',
    'BME': 'Pacific', 'NFB': 'Pacific',
    # CN
    'EDG': 'CN', 'TEC': 'CN', 'FPX': 'CN', 'TYLOO': 'CN', 'NIP': 'CN',
    'TE': 'CN', 'AG': 'CN', 'WOL': 'CN',
}

combined_df['Region'] = combined_df['Team'].map(team_region)
print(combined_df['Region'].value_counts())
print(f"\nUnmapped teams: {combined_df[combined_df['Region'].isna()]['Team'].unique()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 18
#       1 team_region = {
#       2     # Americas
#       3     'MIBR': 'Americas', 'NRG': 'Americas', 'SEN': 'Americas', 'C9': 'Americas',
#    (...)     15     'TE': 'CN', 'AG': 'CN', 'WOL': 'CN',
#      16 }
# ---> 18 combined_df['Region'] = combined_df['Team'].map(team_region)
#      19 print(combined_df['Region'].value_counts())
#      20 print(f"\nUnmapped teams: {combined_df[combined_df['Region'].isna()]['Team'].unique()}")
#
# NameError: name 'combined_df' is not defined

# %%
# Fix unmapped teams
extra_mappings = {
    'BLG': 'CN',
    'XLG': 'CN', 
    'DRG': 'Pacific',
}

combined_df['Region'] = combined_df['Region'].fillna(combined_df['Team'].map(extra_mappings))

# Check remaining unmapped
print(combined_df[combined_df['Region'].isna()][['Player', 'Team']])
print(combined_df['Region'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       1 # Fix unmapped teams
#       2 extra_mappings = {
#       3     'BLG': 'CN',
#       4     'XLG': 'CN',
#       5     'DRG': 'Pacific',
#       6 }
# ----> 8 combined_df['Region'] = combined_df['Region'].fillna(combined_df['Team'].map(extra_mappings))
#      10 # Check remaining unmapped
#      11 print(combined_df[combined_df['Region'].isna()][['Player', 'Team']])
#
# NameError: name 'combined_df' is not defined

# %%
# Drop non-VCT rows (tarik's content creator team)
combined_df = combined_df[~combined_df['Team'].isin(['tarik', 'Team'])]

print(combined_df['Region'].value_counts())
print(f"Total players remaining: {len(combined_df)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Drop non-VCT rows (tarik's content creator team)
# ----> 2 combined_df = combined_df[~combined_df['Team'].isin(['tarik', 'Team'])]
#       4 print(combined_df['Region'].value_counts())
#       5 print(f"Total players remaining: {len(combined_df)}")
#
# NameError: name 'combined_df' is not defined

# %%
combined_df.to_csv('vct_2025_clean.csv', index=False)
print("Saved to vct_2025_clean.csv")
print(combined_df[['Player', 'Team', 'Region', 'ACS', 'ADR', 'KAST', 'Event']].head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 combined_df.to_csv('vct_2025_clean.csv', index=False)
#       2 print("Saved to vct_2025_clean.csv")
#       3 print(combined_df[['Player', 'Team', 'Region', 'ACS', 'ADR', 'KAST', 'Event']].head(10))
#
# NameError: name 'combined_df' is not defined

# %%
# Convert numeric columns
numeric_cols = ['Rnd', 'R2.0', 'ACS', 'K:D', 'ADR', 'KPR', 'APR', 'FKPR', 'FDPR', 'K', 'D', 'A', 'FK', 'FD']

# Remove % from KAST and convert
combined_df['KAST'] = combined_df['KAST'].str.replace('%', '').astype(float)

# Remove % from HS%
combined_df['HS%'] = combined_df['HS%'].str.replace('%', '').astype(float)

for col in numeric_cols:
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

print(combined_df.dtypes)
print(f"\nMissing values:\n{combined_df.isnull().sum()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       2 numeric_cols = ['Rnd', 'R2.0', 'ACS', 'K:D', 'ADR', 'KPR', 'APR', 'FKPR', 'FDPR', 'K', 'D', 'A', 'FK', 'FD']
#       4 # Remove % from KAST and convert
# ----> 5 combined_df['KAST'] = combined_df['KAST'].str.replace('%', '').astype(float)
#       7 # Remove % from HS%
#       8 combined_df['HS%'] = combined_df['HS%'].str.replace('%', '').astype(float)
#
# NameError: name 'combined_df' is not defined

# %%
combined_df.to_csv('vct_2025_clean.csv', index=False)
print("Clean data saved successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 combined_df.to_csv('vct_2025_clean.csv', index=False)
#       2 print("Clean data saved successfully")
#
# NameError: name 'combined_df' is not defined

# %%
# Scrape map stats for each event
map_urls = {
    'Masters Bangkok 2025': 'https://www.vlr.gg/event/matches/2281/valorant-masters-bangkok-2025/?series_id=all',
    'Masters Toronto 2025': 'https://www.vlr.gg/event/matches/2282/valorant-masters-toronto-2025/?series_id=all',
    'Champions 2025': 'https://www.vlr.gg/event/matches/2283/valorant-champions-2025/?series_id=all'
}

headers = {'User-Agent': 'Mozilla/5.0'}

for event_name, url in map_urls.items():
    response = requests.get(url, headers=headers)
    print(f"{event_name}: {response.status_code}")
    print(response.text[:500])
    print('---')
# Out:
# Masters Bangkok 2025: 200
# <!DOCTYPE html>
# <html lang="en" data-theme="light">
# 	<head>
# 		<title>
# 			Valorant Masters Bangkok 2025: Schedule and Results | Valorant Event | VLR.gg		</title>
#
# 					<meta name="description" content="Valorant Masters Bangkok 2025 results, upcoming matches, and VODs">
# 				<meta charset="utf-8">
#
# 		<meta property="og:title" content="Valorant Masters Bangkok 2025: Schedule and Results | Valorant Event | VLR.gg">
# 		<meta property="og:site_name" content="VLR.gg">
#
# 					<meta property="og:description
# ---
# Masters Toronto 2025: 200
# <!DOCTYPE html>
# <html lang="en" data-theme="light">
# 	<head>
# 		<title>
# 			Valorant Masters Toronto 2025: Schedule and Results | Valorant Event | VLR.gg		</title>
#
# 					<meta name="description" content="Valorant Masters Toronto 2025 results, upcoming matches, and VODs">
# 				<meta charset="utf-8">
#
# 		<meta property="og:title" content="Valorant Masters Toronto 2025: Schedule and Results | Valorant Event | VLR.gg">
# 		<meta property="og:site_name" content="VLR.gg">
#
# 					<meta property="og:description
# ---
# Champions 2025: 200
# <!DOCTYPE html>
# <html lang="en" data-theme="light">
# 	<head>
# 		<title>
# 			Valorant Champions 2025: Schedule and Results | Valorant Event | VLR.gg		</title>
#
# 					<meta name="description" content="Valorant Champions 2025 results, upcoming matches, and VODs">
# 				<meta charset="utf-8">
#
# 		<meta property="og:title" content="Valorant Champions 2025: Schedule and Results | Valorant Event | VLR.gg">
# 		<meta property="og:site_name" content="VLR.gg">
#
# 					<meta property="og:description" content="Valoran
# ---

# %%
map_stats_urls = {
    'Masters Bangkok 2025': 'https://www.vlr.gg/event/stats/2281/valorant-masters-bangkok-2025?type=maps',
    'Masters Toronto 2025': 'https://www.vlr.gg/event/stats/2282/valorant-masters-toronto-2025?type=maps',
    'Champions 2025': 'https://www.vlr.gg/event/stats/2283/valorant-champions-2025?type=maps'
}

headers = {'User-Agent': 'Mozilla/5.0'}
all_map_dfs = []

for event_name, url in map_stats_urls.items():
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find('table')
    if table:
        rows = table.find_all('tr')
        data = []
        for row in rows:
            cols = [col.get_text(strip=True) for col in row.find_all(['td', 'th'])]
            if cols:
                data.append(cols)
        df = pd.DataFrame(data[1:], columns=data[0])
        df['Event'] = event_name
        all_map_dfs.append(df)
        print(f"{event_name}: {df.shape[0]} rows")
        print(df.head(3))
    else:
        print(f"{event_name}: no table found")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 12
#      10 for event_name, url in map_stats_urls.items():
#      11     response = requests.get(url, headers=headers)
# ---> 12     soup = BeautifulSoup(response.text, 'html.parser')
#      13     table = soup.find('table')
#      14     if table:
#
# NameError: name 'BeautifulSoup' is not defined

# %%
url = "https://www.vlr.gg/event/2283/valorant-champions-2025/maps"
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
print(response.status_code)
# Find all tables
tables = soup.find_all('table')
print(f"Found {len(tables)} tables")
for i, t in enumerate(tables):
    print(f"\nTable {i}:")
    print(t.get_text(strip=True)[:300])

# %%
# Try the event maps overview page
url = "https://www.vlr.gg/event/2283/valorant-champions-2025"
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# Look for map related divs
map_divs = soup.find_all('div', class_=lambda c: c and 'map' in c.lower())
print(f"Found {len(map_divs)} map divs")
for d in map_divs[:5]:
    print(d.get_text(strip=True)[:200])
    print('---')

# %%
# Regional averages for key metrics
regional_stats = combined_df.groupby('Region')[['ACS', 'ADR', 'KAST', 'KPR', 'APR', 'FKPR', 'FDPR', 'HS%']].mean().round(2)
print(regional_stats)

# %%
from scipy import stats

regions = ['Americas', 'EMEA', 'Pacific', 'CN']
metrics = ['ACS', 'ADR', 'KAST', 'KPR', 'FKPR', 'HS%']

print("Kruskal-Wallis Test Results (p < 0.05 = significant difference between regions):\n")
for metric in metrics:
    groups = [combined_df[combined_df['Region'] == r][metric].dropna() for r in regions]
    stat, p = stats.kruskal(*groups)
    sig = '*** SIGNIFICANT' if p < 0.05 else 'not significant'
    print(f"{metric}: H={stat:.3f}, p={p:.4f} — {sig}")

# %%
from itertools import combinations

metrics_significant = ['KAST', 'HS%']
regions = ['Americas', 'EMEA', 'Pacific', 'CN']

print("Mann-Whitney U Post-Hoc Tests:\n")
for metric in metrics_significant:
    print(f"--- {metric} ---")
    for r1, r2 in combinations(regions, 2):
        group1 = combined_df[combined_df['Region'] == r1][metric].dropna()
        group2 = combined_df[combined_df['Region'] == r2][metric].dropna()
        stat, p = stats.mannwhitneyu(group1, group2, alternative='two-sided')
        sig = '*** SIGNIFICANT' if p < 0.05 else 'not significant'
        print(f"{r1} vs {r2}: p={p:.4f} — {sig}")
    print()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# KAST box plot
sns.boxplot(data=combined_df, x='Region', y='KAST', palette='Set2', ax=axes[0])
axes[0].set_title('KAST% by Region', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Region')
axes[0].set_ylabel('KAST%')

# HS% box plot
sns.boxplot(data=combined_df, x='Region', y='HS%', palette='Set2', ax=axes[1])
axes[1].set_title('Headshot% by Region', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Region')
axes[1].set_ylabel('HS%')

plt.tight_layout()
plt.savefig('kast_hs_boxplots.png', dpi=150)
plt.show()
print("Saved!")

# %%
fig, axes = plt.subplots(2, 4, figsize=(18, 10))
metrics = ['ACS', 'ADR', 'KAST', 'KPR', 'APR', 'FKPR', 'FDPR', 'HS%']

for i, metric in enumerate(metrics):
    ax = axes[i//4][i%4]
    regional_means = combined_df.groupby('Region')[metric].mean()
    colors = ['#2ecc71', '#e74c3c', '#3498db', '#f39c12']
    regional_means.plot(kind='bar', ax=ax, color=colors, edgecolor='black')
    ax.set_title(f'{metric} by Region', fontweight='bold')
    ax.set_xlabel('')
    ax.set_ylabel(metric)
    ax.tick_params(axis='x', rotation=45)

plt.suptitle('VCT 2025 Performance Metrics by Region', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('all_metrics_bar.png', dpi=150)
plt.show()
print("Saved!")

# %%
fig, ax = plt.subplots(figsize=(10, 5))

# Normalise each metric so they're comparable on same scale
from sklearn.preprocessing import MinMaxScaler

heatmap_data = combined_df.groupby('Region')[['ACS', 'ADR', 'KAST', 'KPR', 'APR', 'FKPR', 'FDPR', 'HS%']].mean()
scaler = MinMaxScaler()
heatmap_normalised = pd.DataFrame(scaler.fit_transform(heatmap_data), 
                                   index=heatmap_data.index, 
                                   columns=heatmap_data.columns)

sns.heatmap(heatmap_normalised, annot=True, fmt='.2f', cmap='YlOrRd', 
            linewidths=0.5, ax=ax)
ax.set_title('Normalised Regional Performance Heatmap\n(0=lowest, 1=highest)', 
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('regional_heatmap.png', dpi=150)
plt.show()
print("Saved!")

# %%
import sys
# !{sys.executable} -m pip install scikit-learn

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.violinplot(data=combined_df, x='Region', y='KAST', palette='Set2', ax=axes[0], inner='box')
axes[0].set_title('KAST% Distribution by Region', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Region')
axes[0].set_ylabel('KAST%')

sns.violinplot(data=combined_df, x='Region', y='HS%', palette='Set2', ax=axes[1], inner='box')
axes[1].set_title('HS% Distribution by Region', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Region')
axes[1].set_ylabel('HS%')

plt.tight_layout()
plt.savefig('violin_plots.png', dpi=150)
plt.show()
print("Saved!")

# %%
events = {
    'Masters Bangkok 2025': 'https://www.vlr.gg/event/stats/2281/valorant-masters-bangkok-2025',
    'Masters Toronto 2025': 'https://www.vlr.gg/event/stats/2282/valorant-masters-toronto-2025',
    'Champions 2025': 'https://www.vlr.gg/event/stats/2283/valorant-champions-2025'
}

headers = {'User-Agent': 'Mozilla/5.0'}
all_rows = []

for event_name, url in events.items():
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find('table')
    rows = table.find_all('tr')[1:]
    
    for row in rows:
        cols = row.find_all(['td', 'th'])
        if not cols:
            continue
        
        player = cols[0].find('div', style=lambda s: s and 'font-weight: 700' in s)
        team = cols[0].find('div', class_='stats-player-country')
        
        # Extract agent names from image filenames
        agent_imgs = cols[1].find_all('img')
        agent_names = []
        for img in agent_imgs:
            src = img.get('src', '')
            agent_name = src.split('/')[-1].replace('.png', '').replace('.jpg', '')
            if agent_name:
                agent_names.append(agent_name.capitalize())
        agents_str = ', '.join(agent_names)
        
        player_name = player.get_text(strip=True) if player else ''
        team_name = team.get_text(strip=True) if team else ''
        
        stats = [col.get_text(strip=True) for col in cols[2:]]
        all_rows.append([player_name, team_name, agents_str] + stats + [event_name])

# Get column headers
response = requests.get(list(events.values())[0], headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
header_row = soup.find('table').find('tr')
col_names = ['Player', 'Team', 'Agents'] + [th.get_text(strip=True) for th in header_row.find_all('th')[2:]] + ['Event']

combined_df = pd.DataFrame(all_rows, columns=col_names)
print(combined_df[['Player', 'Team', 'Agents']].head(10))

# %%
# Remove non-VCT rows
combined_df = combined_df[~combined_df['Team'].isin(['tarik', 'Team'])]

# Convert numeric columns
numeric_cols = ['Rnd', 'R2.0', 'ACS', 'K:D', 'ADR', 'KPR', 'APR', 'FKPR', 'FDPR', 'K', 'D', 'A', 'FK', 'FD']
combined_df['KAST'] = combined_df['KAST'].str.replace('%', '').astype(float)
combined_df['HS%'] = combined_df['HS%'].str.replace('%', '').astype(float)
for col in numeric_cols:
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

# Region mapping
team_region = {
    'MIBR': 'Americas', 'NRG': 'Americas', 'SEN': 'Americas', 'C9': 'Americas',
    'EG': 'Americas', 'LOUD': 'Americas', 'LEV': 'Americas', '100T': 'Americas',
    'G2': 'Americas', '2G': 'Americas', 'KRU': 'Americas',
    'TL': 'EMEA', 'TH': 'EMEA', 'FNC': 'EMEA', 'VIT': 'EMEA', 'NAVI': 'EMEA',
    'BBL': 'EMEA', 'GX': 'EMEA', 'KC': 'EMEA', 'M8': 'EMEA', 'FUT': 'EMEA',
    'T1': 'Pacific', 'DRX': 'Pacific', 'PRX': 'Pacific', 'TLN': 'Pacific',
    'TS': 'Pacific', 'GEN': 'Pacific', 'RRQ': 'Pacific', 'ZETA': 'Pacific',
    'BME': 'Pacific', 'NFB': 'Pacific', 'DRG': 'Pacific',
    'EDG': 'CN', 'TEC': 'CN', 'FPX': 'CN', 'TYLOO': 'CN', 'NIP': 'CN',
    'TE': 'CN', 'AG': 'CN', 'WOL': 'CN', 'BLG': 'CN', 'XLG': 'CN',
}

combined_df['Region'] = combined_df['Team'].map(team_region)
print(combined_df['Region'].value_counts())
print(f"Total: {len(combined_df)} players")

# Save
combined_df.to_csv('vct_2025_clean.csv', index=False)
print("Saved!")

# %%
import pandas as pd
df = pd.read_csv('vct_2025_clean.csv')
print(df.columns.tolist())
print(df.shape)

# %%
import pandas as pd

# Load local CSV directly
combined_df = pd.read_csv('vct_2025_clean.csv')
print(combined_df.columns.tolist())
print(combined_df.shape)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

match_links_champions = [
    "https://www.vlr.gg/542195/paper-rex-vs-xi-lai-gaming-valorant-champions-2025-opening-a",
    "https://www.vlr.gg/542196/giantx-vs-sentinels-valorant-champions-2025-opening-a",
    "https://www.vlr.gg/542207/nrg-vs-edward-gaming-valorant-champions-2025-opening-c",
    "https://www.vlr.gg/542205/team-liquid-vs-drx-valorant-champions-2025-opening-c",
    "https://www.vlr.gg/542212/dragon-ranger-gaming-vs-t1-valorant-champions-2025-opening-d",
    "https://www.vlr.gg/542211/g2-esports-vs-team-heretics-valorant-champions-2025-opening-d",
    "https://www.vlr.gg/542200/bilibili-gaming-vs-mibr-valorant-champions-2025-opening-b",
    "https://www.vlr.gg/542201/rex-regum-qeon-vs-fnatic-valorant-champions-2025-opening-b",
    "https://www.vlr.gg/542197/paper-rex-vs-giantx-valorant-champions-2025-winners-a",
    "https://www.vlr.gg/542208/drx-vs-nrg-valorant-champions-2025-winners-c",
    "https://www.vlr.gg/542213/team-heretics-vs-t1-valorant-champions-2025-winners-d",
    "https://www.vlr.gg/542202/mibr-vs-fnatic-valorant-champions-2025-winners-b",
    "https://www.vlr.gg/542209/team-liquid-vs-edward-gaming-valorant-champions-2025-elim-c",
    "https://www.vlr.gg/542198/xi-lai-gaming-vs-sentinels-valorant-champions-2025-elim-a",
    "https://www.vlr.gg/542203/bilibili-gaming-vs-rex-regum-qeon-valorant-champions-2025-elim-b",
    "https://www.vlr.gg/542214/g2-esports-vs-dragon-ranger-gaming-valorant-champions-2025-elim-d",
    "https://www.vlr.gg/542210/drx-vs-team-liquid-valorant-champions-2025-decider-c",
    "https://www.vlr.gg/542199/giantx-vs-xi-lai-gaming-valorant-champions-2025-decider-a",
    "https://www.vlr.gg/542215/t1-vs-g2-esports-valorant-champions-2025-decider-d",
    "https://www.vlr.gg/542204/mibr-vs-rex-regum-qeon-valorant-champions-2025-decider-b",
    "https://www.vlr.gg/542265/paper-rex-vs-g2-esports-valorant-champions-2025-ubqf",
    "https://www.vlr.gg/542264/fnatic-vs-drx-valorant-champions-2025-ubqf",
    "https://www.vlr.gg/542266/team-heretics-vs-mibr-valorant-champions-2025-ubqf",
    "https://www.vlr.gg/542267/nrg-vs-giantx-valorant-champions-2025-ubqf",
    "https://www.vlr.gg/542273/drx-vs-g2-esports-valorant-champions-2025-lr1",
    "https://www.vlr.gg/542274/team-heretics-vs-giantx-valorant-champions-2025-lr1",
    "https://www.vlr.gg/542268/fnatic-vs-paper-rex-valorant-champions-2025-ubsf",
    "https://www.vlr.gg/542269/mibr-vs-nrg-valorant-champions-2025-ubsf",
    "https://www.vlr.gg/542277/paper-rex-vs-team-heretics-valorant-champions-2025-lr2",
    "https://www.vlr.gg/542276/mibr-vs-drx-valorant-champions-2025-lr2",
    "https://www.vlr.gg/542270/fnatic-vs-nrg-valorant-champions-2025-ubf",
    "https://www.vlr.gg/542278/drx-vs-paper-rex-valorant-champions-2025-lr3",
    "https://www.vlr.gg/542279/fnatic-vs-drx-valorant-champions-2025-lbf",
    "https://www.vlr.gg/542272/nrg-vs-fnatic-valorant-champions-2025-gf"
]

headers = {'User-Agent': 'Mozilla/5.0'}
map_rows = []

for url in match_links_champions:
    try:
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Get team names
        teams = [t.get_text(strip=True) for t in soup.select('.match-header-link-name .wf-title-med')]
        team1 = teams[0] if len(teams) > 0 else 'Unknown'
        team2 = teams[1] if len(teams) > 1 else 'Unknown'
        
        # Get maps played
        games = soup.select('.vm-stats-game')
        for game in games:
            map_div = game.select_one('.map')
            if not map_div:
                continue
            map_name = map_div.get_text(strip=True).replace('PICK', '').replace('BAN', '').strip()
            map_name = map_name.split('\n')[0].strip()
            
            scores = game.select('.score')
            if len(scores) >= 2:
                try:
                    score1 = int(scores[0].get_text(strip=True))
                    score2 = int(scores[1].get_text(strip=True))
                    winner = team1 if score1 > score2 else team2
                    map_rows.append({
                        'Event': 'Champions 2025',
                        'Team1': team1,
                        'Team2': team2,
                        'Map': map_name,
                        'Score1': score1,
                        'Score2': score2,
                        'Winner': winner
                    })
                except:
                    pass
        time.sleep(0.5)
    except Exception as e:
        print(f"Error: {url} — {e}")

maps_df = pd.DataFrame(map_rows)
print(f"Scraped {len(maps_df)} map results")
print(maps_df['Map'].value_counts())
# Out:
# Scraped 88 map results
# Map
# Bind48:56       1
# Sunset39:04     1
# Corrode41:17    1
# Sunset38:15     1
# Haven51:34      1
#                ..
# Corrode40:34    1
# Lotus44:48      1
# Abyss1:03:33    1
# Ascent52:47     1
# Sunset42:18     1
# Name: count, Length: 88, dtype: int64

# %%
# Clean map names
maps_df['Map'] = maps_df['Map'].str.replace(r'\d+:\d+', '', regex=True).str.strip()
maps_df['Map'] = maps_df['Map'].str.replace(r'\s+', ' ', regex=True).str.strip()

print(f"Total maps played: {len(maps_df)}")
print("\nMap pick counts:")
print(maps_df['Map'].value_counts())
# Out:
# Total maps played: 88
#
# Map pick counts:
# Map
# Lotus         17
# Abyss         11
# Bind          10
# Sunset        10
# Corrode       10
# Haven          9
# Ascent         8
# Abyss:38       1
# Lotus:38       1
# Sunset:05      1
# Bind:45        1
# Corrode:55     1
# Haven:52       1
# Corrode:32     1
# Abyss:57       1
# Corrode:54     1
# Ascent:08      1
# Ascent:02      1
# Ascent:34      1
# Abyss:33       1
# Name: count, dtype: int64

# %%
import re
maps_df['Map'] = maps_df['Map'].apply(lambda x: re.split(r'\d', x)[0].strip())
print(maps_df['Map'].value_counts())
# Out:
# Map
# Lotus       17
# Abyss       11
# Bind        10
# Sunset      10
# Corrode     10
# Haven        9
# Ascent       8
# Abyss:       3
# Corrode:     3
# Ascent:      3
# Lotus:       1
# Sunset:      1
# Bind:        1
# Haven:       1
# Name: count, dtype: int64

# %%
# Remove anything after and including a colon, then strip whitespace
maps_df['Map'] = maps_df['Map'].str.split(':').str[0].str.strip()
print(maps_df['Map'].value_counts())
print(f"\nTotal maps: {len(maps_df)}")
# Out:
# Map
# Lotus      18
# Abyss      14
# Corrode    13
# Bind       11
# Sunset     11
# Ascent     11
# Haven      10
# Name: count, dtype: int64
#
# Total maps: 88

# %%
# Masters Bangkok 2025 match links
match_links_bangkok = []
match_links_toronto = []

import requests
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0'}

# Get Bangkok match links
response = requests.get('https://www.vlr.gg/event/matches/2281/valorant-masters-bangkok-2025/?series_id=all', headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
match_links_bangkok = ['https://www.vlr.gg' + a['href'] for a in soup.select('a.match-item')]
print(f"Bangkok matches: {len(match_links_bangkok)}")

# Get Toronto match links
response = requests.get('https://www.vlr.gg/event/matches/2282/valorant-masters-toronto-2025/?series_id=all', headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
match_links_toronto = ['https://www.vlr.gg' + a['href'] for a in soup.select('a.match-item')]
print(f"Toronto matches: {len(match_links_toronto)}")
# Out:
# Bangkok matches: 17
# Toronto matches: 25

# %%
all_match_links = (
    [('Bangkok 2025', url) for url in match_links_bangkok] +
    [('Toronto 2025', url) for url in match_links_toronto]
)

import re

for event_name, url in all_match_links:
    try:
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        teams = [t.get_text(strip=True) for t in soup.select('.match-header-link-name .wf-title-med')]
        team1 = teams[0] if len(teams) > 0 else 'Unknown'
        team2 = teams[1] if len(teams) > 1 else 'Unknown'
        
        games = soup.select('.vm-stats-game')
        for game in games:
            map_div = game.select_one('.map')
            if not map_div:
                continue
            map_name = map_div.get_text(strip=True)
            map_name = re.split(r'\d', map_name)[0].strip()
            map_name = map_name.split(':')[0].strip()
            
            scores = game.select('.score')
            if len(scores) >= 2:
                try:
                    score1 = int(scores[0].get_text(strip=True))
                    score2 = int(scores[1].get_text(strip=True))
                    winner = team1 if score1 > score2 else team2
                    map_rows.append({
                        'Event': f'Masters {event_name}',
                        'Team1': team1,
                        'Team2': team2,
                        'Map': map_name,
                        'Score1': score1,
                        'Score2': score2,
                        'Winner': winner
                    })
                except:
                    pass
        time.sleep(0.5)
    except Exception as e:
        print(f"Error: {url} — {e}")

maps_df = pd.DataFrame(map_rows)
maps_df['Map'] = maps_df['Map'].str.split(':').str[0].str.strip()
print(f"Total maps scraped: {len(maps_df)}")
print(maps_df.groupby(['Event', 'Map']).size().unstack(fill_value=0))
# Out:
# Total maps scraped: 294
# Map                   Abyss1  Abyss39  Abyss40  Abyss44  Abyss45  Abyss46  \
# Event
# Champions 2025             3        2        2        1        2        1
# Masters Bangkok 2025       0        0        0        0        0        0
# Masters Toronto 2025       0        0        0        0        0        0
#
# Map                   Abyss47  Abyss51  Abyss56  AbyssPICK  ...  Sunset38  \
# Event                                                       ...
# Champions 2025              1        1        1          0  ...         2
# Masters Bangkok 2025        0        0        0          8  ...         0
# Masters Toronto 2025        0        0        0          0  ...         0
#
# Map                   Sunset39  Sunset40  Sunset41  Sunset42  Sunset46  \
# Event
# Champions 2025               1         1         1         1         1
# Masters Bangkok 2025         0         0         0         0         0
# Masters Toronto 2025         0         0         0         0         0
#
# Map                   Sunset47  Sunset48  Sunset51  SunsetPICK
# Event
# Champions 2025               1         1         1           0
# Masters Bangkok 2025         0         0         0           0
# Masters Toronto 2025         0         0         0          18
#
# [3 rows x 85 columns]

# %%
import re

# Clean map names properly - keep only alphabetical characters at the start
def clean_map_name(name):
    # Extract only the map name (letters only from the start)
    match = re.match(r'^([A-Za-z]+)', str(name).strip())
    if match:
        return match.group(1)
    return name

maps_df['Map'] = maps_df['Map'].apply(clean_map_name)
print(maps_df['Map'].value_counts())
print(f"\nTotal maps: {len(maps_df)}")
print(f"\nEvents covered:")
print(maps_df['Event'].value_counts())
# Out:
# Map
# LotusPICK       38
# SplitPICK       28
# HavenPICK       24
# Lotus           22
# IceboxPICK      18
# SunsetPICK      18
# Sunset          15
# Corrode         15
# Ascent          15
# Abyss           14
# Bind            13
# PearlPICK       12
# BindPICK        12
# AscentPICK      12
# Haven           10
# AbyssPICK        8
# FracturePICK     6
# Split            4
# Pearl            4
# Icebox           4
# Fracture         2
# Name: count, dtype: int64
#
# Total maps: 294
#
# Events covered:
# Event
# Masters Toronto 2025    120
# Champions 2025           88
# Masters Bangkok 2025     86
# Name: count, dtype: int64

# %%
# Final clean — remove PICK, BAN and anything non-alphabetical at the end
maps_df['Map'] = maps_df['Map'].str.replace('PICK', '').str.replace('BAN', '').str.strip()

print(maps_df['Map'].value_counts())
print(f"\nBy event:")
print(maps_df.groupby(['Event', 'Map']).size().unstack(fill_value=0))
# Out:
# Map
# Lotus       60
# Haven       34
# Sunset      33
# Split       32
# Ascent      27
# Bind        25
# Abyss       22
# Icebox      22
# Pearl       16
# Corrode     15
# Fracture     8
# Name: count, dtype: int64
#
# By event:
# Map                   Abyss  Ascent  Bind  Corrode  Fracture  Haven  Icebox  \
# Event
# Champions 2025           14      11    11       13         0     10       0
# Masters Bangkok 2025      8       2    14        0         8     12       0
# Masters Toronto 2025      0      14     0        2         0     12      22
#
# Map                   Lotus  Pearl  Split  Sunset
# Event
# Champions 2025           18      0      0      11
# Masters Bangkok 2025     18     10     14       0
# Masters Toronto 2025     24      6     18      22

# %%
# Add region mapping for teams
team_region = {
    'MIBR': 'Americas', 'NRG': 'Americas', 'SEN': 'Americas', 'C9': 'Americas',
    'EG': 'Americas', 'LOUD': 'Americas', 'LEV': 'Americas', '100T': 'Americas',
    'G2': 'Americas', '2G': 'Americas', 'KRU': 'Americas',
    'TL': 'EMEA', 'TH': 'EMEA', 'FNC': 'EMEA', 'VIT': 'EMEA', 'NAVI': 'EMEA',
    'BBL': 'EMEA', 'GX': 'EMEA', 'KC': 'EMEA', 'M8': 'EMEA', 'FUT': 'EMEA',
    'FNC': 'EMEA', 'FNATIC': 'EMEA', 'GIANTX': 'EMEA', 'TH': 'EMEA',
    'Team Heretics': 'EMEA', 'Team Liquid': 'EMEA', 'FNATIC': 'EMEA',
    'G2 Esports': 'Americas', 'NRG': 'Americas', 'MIBR': 'Americas',
    'T1': 'Pacific', 'DRX': 'Pacific', 'PRX': 'Pacific', 'Paper Rex': 'Pacific',
    'GEN': 'Pacific', 'RRQ': 'Pacific', 'ZETA': 'Pacific', 'BME': 'Pacific',
    'Dragon Ranger Gaming': 'Pacific', 'Xi Lai Gaming': 'CN',
    'Rex Regum Qeon': 'Pacific', 'Bilibili Gaming': 'CN',
    'Edward Gaming': 'CN', 'EDG': 'CN', 'TEC': 'CN', 'FPX': 'CN',
    'BLG': 'CN', 'XLG': 'CN', 'WOL': 'CN',
}

maps_df['Region1'] = maps_df['Team1'].map(team_region)
maps_df['Region2'] = maps_df['Team2'].map(team_region)

print(maps_df[['Team1', 'Region1', 'Team2', 'Region2', 'Map', 'Event']].head(10))
print(f"\nUnmapped Team1: {maps_df[maps_df['Region1'].isna()]['Team1'].unique()}")
print(f"Unmapped Team2: {maps_df[maps_df['Region2'].isna()]['Team2'].unique()}")
# Out:
#                   Team1   Region1          Team2  Region2      Map  \
# 0             Paper Rex   Pacific  Xi Lai Gaming       CN     Bind
# 1             Paper Rex   Pacific  Xi Lai Gaming       CN   Sunset
# 2                GIANTX      EMEA      Sentinels      NaN  Corrode
# 3                GIANTX      EMEA      Sentinels      NaN   Sunset
# 4                GIANTX      EMEA      Sentinels      NaN    Haven
# 5                   NRG  Americas  EDward Gaming      NaN    Abyss
# 6                   NRG  Americas  EDward Gaming      NaN  Corrode
# 7           Team Liquid      EMEA            DRX  Pacific    Abyss
# 8           Team Liquid      EMEA            DRX  Pacific     Bind
# 9  Dragon Ranger Gaming   Pacific             T1  Pacific    Lotus
#
#             Event
# 0  Champions 2025
# 1  Champions 2025
# 2  Champions 2025
# 3  Champions 2025
# 4  Champions 2025
# 5  Champions 2025
# 6  Champions 2025
# 7  Champions 2025
# 8  Champions 2025
# 9  Champions 2025
#
# Unmapped Team1: <StringArray>
# ['Guangzhou Huadu Bilibili Gaming(Bilibili Gaming)',
#                                     'EDward Gaming',
#                                     'Team Vitality',
#                                'Team International',
#                                         'Sentinels',
#                                             'Gen.G',
#                                    'Wolves Esports',
#                                        'Team tarik']
# Length: 8, dtype: str
# Unmapped Team2: <StringArray>
# [     'Sentinels',  'EDward Gaming',  'Trace Esports',  'Team Vitality',
#   'Team Thailand', 'Wolves Esports',          'Gen.G',     'Team Toast']
# Length: 8, dtype: str

# %%
# Fix unmapped teams
extra_teams = {
    'Sentinels': 'Americas',
    'EDward Gaming': 'CN',
    'Guangzhou Huadu Bilibili Gaming(Bilibili Gaming)': 'CN',
    'Bilibili Gaming': 'CN',
    'Team Vitality': 'EMEA',
    'Team International': 'Pacific',
    'Wolves Esports': 'CN',
    'Team tarik': 'Americas',
    'Gen.G': 'Pacific',
    'Trace Esports': 'CN',
    'Team Thailand': 'Pacific',
    'Team Toast': 'Americas',
    'Rex Regum Qeon': 'Pacific',
    'Dragon Ranger Gaming': 'Pacific',
    'Xi Lai Gaming': 'CN',
}

maps_df['Region1'] = maps_df['Region1'].fillna(maps_df['Team1'].map(extra_teams))
maps_df['Region2'] = maps_df['Region2'].fillna(maps_df['Team2'].map(extra_teams))

print(f"Remaining unmapped Region1: {maps_df[maps_df['Region1'].isna()]['Team1'].unique()}")
print(f"Remaining unmapped Region2: {maps_df[maps_df['Region2'].isna()]['Team2'].unique()}")
print(f"\nTotal maps: {len(maps_df)}")

# Save
maps_df.to_csv('vct_2025_maps.csv', index=False)
print("Saved to vct_2025_maps.csv")
# Out:
# Remaining unmapped Region1: <StringArray>
# []
# Length: 0, dtype: str
# Remaining unmapped Region2: <StringArray>
# []
# Length: 0, dtype: str
#
# Total maps: 294
# Saved to vct_2025_maps.csv
